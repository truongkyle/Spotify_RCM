# %%
import spotipy.util as util
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import json

# %%
username = 'XavieLee'
client_id ='606d591798ae45dfa9ff39ad26e4c951'
client_secret = '145e4049646b4997b68472f460775c26'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'

# %%
token = util.prompt_for_user_token(username=username, 
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri)

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(username=username, 
                                   scope=scope, 
                                   client_id=client_id,   
                                   client_secret=client_secret,     
                                   redirect_uri=redirect_uri))

# %%
recently_played_tracks = sp.current_user_recently_played(limit=10)
print(json.dumps(recently_played_tracks, indent=4))
# Out:
# {
#     "items": [
#         {
#             "track": {
#                 "album": {
#                     "album_type": "single",
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/4bPYvyUn1mWwUwIW57oST2"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/4bPYvyUn1mWwUwIW57oST2",
#                             "id": "4bPYvyUn1mWwUwIW57oST2",
#                             "name": "Emcee L (Da LAB)",
#                             "type": "artist",
#                             "uri": "spotify:artist:4bPYvyUn1mWwUwIW57oST2"
#                         },
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/6zUWZmyi5MLOEynQ5wCI5f"
#                             },
# ...
